# %% [markdown]
# # Assignment/Task 5
# GO_STP_6970
#
#
# Pandas - Data Analysis of IMDB movies data
# As we have a basic understanding of the different data structures in Pandas, let’s explore the fun and interesting ‘IMDB-movies-dataset’ and get our hands dirty by performing practical data analysis on real data.
#
# It is an open-source dataset and you can download it from this link.
#
# We will read the data from the .csv file and perform the following basic operations on movies data
#
# Load the IMDb Dataset and read
# View the dataset
# Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.
# Data Selection – Indexing and Slicing data
# Data Selection – Based on Conditional filtering
# Groupby operations
# Sorting operation
# Dealing with missing values
# Dropping columns and null values
# Apply( ) functions

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("IMDB-Movie-Data.csv")
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# #View the dataset

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
data.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [markdown]
# # Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.size
# Out:
# 12000

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
data.nunique()
# Out:
# Rank                  1000
# Title                  999
# Genre                  207
# Description           1000
# Director               644
# Actors                 996
# Year                    11
# Runtime (Minutes)       94
# Rating                  55
# Votes                  997
# Revenue (Millions)     814
# Metascore               84
# dtype: int64

# %%
data["Genre"].value_counts()
# Out:
# Action,Adventure,Sci-Fi    50
# Drama                      48
# Comedy,Drama,Romance       35
# Comedy                     32
# Drama,Romance              31
#                            ..
# Horror,Mystery,Sci-Fi       1
# Action,Thriller,War         1
# Drama,Mystery,War           1
# Drama,Fantasy,Musical       1
# Animation,Drama,Fantasy     1
# Name: Genre, Length: 207, dtype: int64

# %%
data["Director"].value_counts()
# Out:
# Ridley Scott          8
# Paul W.S. Anderson    6
# Michael Bay           6
# David Yates           6
# M. Night Shyamalan    6
#                      ..
# Jon S. Baird          1
# Mark Mylod            1
# Ava DuVernay          1
# Scott Waugh           1
# Brad Peyton           1
# Name: Director, Length: 644, dtype: int64

# %% [markdown]
# # 4. Data Selection – Indexing and Slicing data

# %%
data[["Title","Genre","Description"]].head()
#indexing using column
# Out:
#                      Title                     Genre  \
# 0  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1               Prometheus  Adventure,Mystery,Sci-Fi
# 2                    Split           Horror,Thriller
# 3                     Sing   Animation,Comedy,Family
# 4            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description
# 0  A group of intergalactic criminals are forced ...
# 1  Following clues to the origin of mankind, a te...
# 2  Three girls are kidnapped by a man with a diag...
# 3  In a city of humanoid animals, a hustling thea...
# 4  A secret government agency recruits some of th...

# %%
#indexing using loc() and iloc()
data.loc[[0,1,2,3,4],["Title","Genre","Description"]]
# Out:
#                      Title                     Genre  \
# 0  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1               Prometheus  Adventure,Mystery,Sci-Fi
# 2                    Split           Horror,Thriller
# 3                     Sing   Animation,Comedy,Family
# 4            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description
# 0  A group of intergalactic criminals are forced ...
# 1  Following clues to the origin of mankind, a te...
# 2  Three girls are kidnapped by a man with a diag...
# 3  In a city of humanoid animals, a hustling thea...
# 4  A secret government agency recruits some of th...

# %%
data.iloc[0,1]
# Out:
# 'Guardians of the Galaxy'

# %%
data.iloc[1:20]
# Out:
#     Rank                                    Title                       Genre  \
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# ...

# %%
#slicing
data[1:5]
# Out:
#    Rank          Title                     Genre  \
# 1     2     Prometheus  Adventure,Mystery,Sci-Fi
# 2     3          Split           Horror,Thriller
# 3     4           Sing   Animation,Comedy,Family
# 4     5  Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# ...

# %% [markdown]
# # 5. Data Selection – Based on Conditional filtering

# %%
data.filter(items=['Rank', 'Votes'])
data['Rating']>7
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Rating, Length: 1000, dtype: bool

# %%
data[data["Year"]>2012].head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
# 5     6           The Great Wall  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# 5  European mercenaries searching for black powde...           Yimou Zhang
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # 6. Groupby operations

# %%
data.groupby("Genre").sum()
# Out:
#                             Rank   Year  Runtime (Minutes)  Rating    Votes  \
# Genre
# Action                       705   4032                176    12.3    17237
# Action,Adventure             999   6033                373    19.2  1003377
# Action,Adventure,Biography   568   4031                263    14.0    97560
# Action,Adventure,Comedy     5700  28199               1535    92.3  2709033
# Action,Adventure,Crime      2379  12074                699    38.6  1201937
# ...                          ...    ...                ...     ...      ...
# Romance,Sci-Fi,Thriller      707   2011                106     7.1   208632
# Sci-Fi                       801   4032                213     9.9     1453
# Sci-Fi,Thriller              513   2008                 91     5.0   170897
# Thriller                    6133  18133                857    53.6   305642
# Thriller,War                 161   2016                106     6.0     5926
#
# ...

# %%
data.groupby(["Genre","Year"]).sum()
# Out:
#                                  Rank  Runtime (Minutes)  Rating   Votes  \
# Genre                      Year
# Action                     2016   705                176    12.3   17237
# Action,Adventure           2007   345                139     6.2  406219
#                            2012   369                136     7.0  474320
#                            2014   285                 98     6.0  122838
# Action,Adventure,Biography 2015   559                122     6.9   90372
# ...                               ...                ...     ...     ...
# Sci-Fi,Thriller            2008   513                 91     5.0  170897
# Thriller                   2007   283                113     7.1  220236
#                            2014   730                100     6.7   71069
#                            2016  5120                644    39.8   14337
# Thriller,War               2016   161                106     6.0    5926
#
# ...

# %% [markdown]
# 7. Sorting operation

# %%
data.sort_values("Rating").head()
# Out:
#      Rank                    Title                     Genre  \
# 829   830           Disaster Movie                    Comedy
# 42     43  Don't Fuck in the Woods                    Horror
# 871   872     Dragonball Evolution  Action,Adventure,Fantasy
# 647   648                 Tall Men   Fantasy,Horror,Thriller
# 968   969                  Wrecker    Action,Horror,Thriller
#
#                                            Description           Director  \
# 829  Over the course of one evening, an unsuspectin...    Jason Friedberg
# 42   A group of friends are going on a camping trip...      Shawn Burkett
# 871  The young warrior Son Goku sets out on a quest...         James Wong
# 647  A challenged man is stalked by tall phantoms i...  Jonathan Holbrook
# 968  Best friends Emily and Lesley go on a road tri...     Micheal Bafaro
#
#                                                 Actors  Year  \
# 829  Carmen Electra, Vanessa Lachey,Nicole Parker, ...  2008
# ...

# %%
data.sort_values("Rating",ascending=False).head()
# Out:
#      Rank            Title                    Genre  \
# 54     55  The Dark Knight       Action,Crime,Drama
# 80     81        Inception  Action,Adventure,Sci-Fi
# 117   118           Dangal   Action,Biography,Drama
# 36     37     Interstellar   Adventure,Drama,Sci-Fi
# 96     97    Kimi no na wa  Animation,Drama,Fantasy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 96   Two strangers find themselves linked in a biza...     Makoto Shinkai
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# ...

# %% [markdown]
# # 8. Dealing with missing values

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # 9. Dropping columns and null values

# %%
data=pd.read_csv("IMDB-Movie-Data.csv")
data.isna().any()
# Out:
# Rank                  False
# Title                 False
# Genre                 False
# Description           False
# Director              False
# Actors                False
# Year                  False
# Runtime (Minutes)     False
# Rating                False
# Votes                 False
# Revenue (Millions)     True
# Metascore              True
# dtype: bool

# %%
data=data.dropna() #droping na value

#checking again

data.isna().any()
# Out:
# Rank                  False
# Title                 False
# Genre                 False
# Description           False
# Director              False
# Actors                False
# Year                  False
# Runtime (Minutes)     False
# Rating                False
# Votes                 False
# Revenue (Millions)    False
# Metascore             False
# dtype: bool

# %% [markdown]
# # 10. Apply( ) functions

# %%
rank = data.apply(lambda n: n*5)

print(rank.head())
# Out:
#    Rank                                              Title  \
# 0     5  Guardians of the GalaxyGuardians of the Galaxy...
# 1    10  PrometheusPrometheusPrometheusPrometheusPromet...
# 2    15                          SplitSplitSplitSplitSplit
# 3    20                               SingSingSingSingSing
# 4    25  Suicide SquadSuicide SquadSuicide SquadSuicide...
#
#                                                Genre  \
# 0  Action,Adventure,Sci-FiAction,Adventure,Sci-Fi...
# 1  Adventure,Mystery,Sci-FiAdventure,Mystery,Sci-...
# 2  Horror,ThrillerHorror,ThrillerHorror,ThrillerH...
# 3  Animation,Comedy,FamilyAnimation,Comedy,Family...
# 4  Action,Adventure,FantasyAction,Adventure,Fanta...
#
#                                          Description  \
# 0  A group of intergalactic criminals are forced ...
# 1  Following clues to the origin of mankind, a te...
# 2  Three girls are kidnapped by a man with a diag...
# 3  In a city of humanoid animals, a hustling thea...
# ...
